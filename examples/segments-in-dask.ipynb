# %%
import numpy as np
from photon_mosaic.core.generators import generate_random_imaging

imaging = generate_random_imaging(num_frames=[1000, 100], height=128, width=128, num_planes=3, sampling_frequency=30.0, seed=42)
segment = imaging.segments[0]

# %%
from photon_mosaic.core.arrayimaging import ArrayImaging
array_imaging = ArrayImaging(segment, sampling_frequency=30.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 from photon_mosaic.core.arrayimaging import ArrayImaging
# ----> 2 array_imaging = ArrayImaging(segment, sampling_frequency=30.0)
#
# File ~\repos\photon-mosaic\src\photon_mosaic\core\arrayimaging.py:52, in ArrayImaging.__init__(self, imaging_series, sampling_frequency, time_vectors, plane_ids, seed)
#      50     videos = imaging_series
#      51 else:
# ---> 52     raise ValueError("'timeseries' must be a numpy array or dask array, or a list of them")
#      54 num_segments = len(videos)
#      55 self._sampling_frequency = float(sampling_frequency)
#
# ValueError: 'timeseries' must be a numpy array or dask array, or a list of them

# %%
imaging[0, 10:20, 40:60, 20:30, :3].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 imaging[0, 10:20, 40:60, 20:30, :3].shape
#
# TypeError: 'NumpyImaging' object is not subscriptable

# %%
imaging[0,:,:,:]
# Out:
# array([[[[7.73956049e-01, 4.38878440e-01, 8.58597920e-01],
#          [6.97368029e-01, 9.41773479e-02, 9.75622352e-01],
#          [7.61139702e-01, 7.86064305e-01, 1.28113633e-01],
#          ...,
#          [1.47783373e-01, 9.36127463e-01, 4.37904037e-01],
#          [3.83319823e-01, 7.29685709e-01, 5.52993065e-01],
#          [9.36139987e-01, 7.80301494e-01, 4.79369564e-01]],
#
#         [[3.76359473e-01, 9.86631545e-01, 7.17760236e-01],
#          [9.51194660e-01, 1.18478577e-01, 8.50533679e-01],
#          [6.37073884e-01, 1.21921678e-01, 5.88258000e-01],
#          ...,
#          [4.60769605e-01, 7.11558042e-01, 1.50454012e-01],
#          [4.73740200e-02, 1.38205372e-01, 9.18823194e-01],
#          [9.25978182e-03, 1.88321975e-01, 3.12835129e-02]],
#
#         [[1.10629468e-01, 6.20149287e-01, 2.41638909e-01],
#          [5.69212050e-01, 5.90195383e-01, 8.49435333e-01],
#          [4.74139291e-03, 8.53369459e-01, 6.19119086e-01],
#          ...,
# ...

# %%
video = imaging.get_series(0, 100, segment_index=0)

# %%
dir(imaging)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_annotations',
#  '_average_image',
#  '_check_segment_index',
#  '_dtype',
#  '_extra_copy_metadata',
#  '_extra_metadata_from_folder',
#  '_extra_metadata_to_folder',
#  '_get_common_repr_html',
#  '_get_file_path',
#  '_get_t_starts',
#  '_get_time_vectors',
#  '_image_shape',
#  '_kwargs',
#  '_main_annotations',
#  '_main_ids',
#  '_main_properties',
#  '_precomputable_kwarg_names',
#  '_preferred_mp_context',
# ...

# %%
imaging.dask_segments[1]
# Out:
# dask.array<array, shape=(100, 128, 128, 3), dtype=float64, chunksize=(100, 128, 128, 3), chunktype=numpy.ndarray>

# %%
video
# Out:
# array([[[[7.73956049e-01, 4.38878440e-01, 8.58597920e-01],
#          [6.97368029e-01, 9.41773479e-02, 9.75622352e-01],
#          [7.61139702e-01, 7.86064305e-01, 1.28113633e-01],
#          ...,
#          [1.47783373e-01, 9.36127463e-01, 4.37904037e-01],
#          [3.83319823e-01, 7.29685709e-01, 5.52993065e-01],
#          [9.36139987e-01, 7.80301494e-01, 4.79369564e-01]],
#
#         [[3.76359473e-01, 9.86631545e-01, 7.17760236e-01],
#          [9.51194660e-01, 1.18478577e-01, 8.50533679e-01],
#          [6.37073884e-01, 1.21921678e-01, 5.88258000e-01],
#          ...,
#          [4.60769605e-01, 7.11558042e-01, 1.50454012e-01],
#          [4.73740200e-02, 1.38205372e-01, 9.18823194e-01],
#          [9.25978182e-03, 1.88321975e-01, 3.12835129e-02]],
#
#         [[1.10629468e-01, 6.20149287e-01, 2.41638909e-01],
#          [5.69212050e-01, 5.90195383e-01, 8.49435333e-01],
#          [4.74139291e-03, 8.53369459e-01, 6.19119086e-01],
#          ...,
# ...
